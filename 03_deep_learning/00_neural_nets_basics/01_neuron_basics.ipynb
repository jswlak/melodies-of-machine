# %% [markdown]
# # **1. What is a Neuron?**
#
# A neuron takes inputs, multiplies them with weights, adds bias, and passes the result through an activation function.

# %% [markdown]
# ![Screenshot 2025-08-05 at 3.15.28 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Single Neuron**

# %%
import numpy as np

# Input features (x1, x2, x3)
X = np.array([0.5, 0.3, 0.2])

# Weights for the inputs
W = np.array([0.4, 0.7, 0.1])

# Bias
b = 0.2

# Linear combination (z = w1*x1 + w2*x2 + w3*x3 + b)
z = np.dot(W, X) + b
print("Weighted sum (z):", z)
# Out:
# Weighted sum (z): 0.6300000000000001

# %% [markdown]
# ![Screenshot 2025-08-05 at 3.28.17 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Activation Functions**
#
#
# *   Sigmoid
# *   ReLU
# *   Tanh

# %% [markdown]
# **Sigmoid**

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

a = sigmoid(z)
print("Sigmoid activation (a):", a)
# Out:
# Sigmoid activation (a): 0.6524894621927444

# %% [markdown]
# **ReLU**

# %%
def relu(z):
    return np.maximum(0, z)

print("ReLU activation:", relu(z))
# Out:
# ReLU activation: 0.6300000000000001

# %% [markdown]
# **Tanh**

# %%
def tanh(z):
    return np.tanh(z)

print("Tanh activation:", tanh(z))
# Out:
# Tanh activation: 0.5580522155596244

# %% [markdown]
# # **Wrap as a Neuron Class**

# %%
class Neuron:
    def __init__(self, weights, bias):
        self.weights = np.array(weights)
        self.bias = bias

    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def forward(self, x):
        z = np.dot(self.weights, x) + self.bias
        return self.sigmoid(z)

neuron = Neuron([0.4, 0.7, 0.1], 0.2)
output = neuron.forward([0.5, 0.3, 0.2])
print("Neuron output:", output)
# Out:
# Neuron output: 0.6524894621927444
